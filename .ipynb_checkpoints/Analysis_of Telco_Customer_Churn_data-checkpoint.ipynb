# %% [markdown]
# # Analysis of Telco Customer Churn data  Project
#
#  copyright by pierian Data Inc.
#
#
# **this dataset is from Kaggle Telco Customer Churn. https://www.kaggle.com/datasets/blastchar/telco-customer-churn**
#
#
# ## GOAL: Create a model to predict whether or not a customer will Churn .

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('../DATA/Telco-Customer-Churn.csv')

# %%
df.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %%
df.tail()
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 7027  6840-RESVB    Male              0     Yes        Yes      24
# 7028  2234-XADUH  Female              0     Yes        Yes      72
# 7029  4801-JZAZL  Female              0     Yes        Yes      11
# 7030  8361-LTMKD    Male              1     Yes         No       4
# 7031  3186-AJIEK    Male              0      No         No      66
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# 7027          Yes               Yes             DSL            Yes  ...
# 7028          Yes               Yes     Fiber optic             No  ...
# 7029           No  No phone service             DSL            Yes  ...
# 7030          Yes               Yes     Fiber optic             No  ...
# 7031          Yes                No     Fiber optic            Yes  ...
#
#      DeviceProtection TechSupport StreamingTV StreamingMovies        Contract  \
# ...

# %% [markdown]
# ## Quick Data Check

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7032 entries, 0 to 7031
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7032 non-null   object
#  1   gender            7032 non-null   object
#  2   SeniorCitizen     7032 non-null   int64
#  3   Partner           7032 non-null   object
#  4   Dependents        7032 non-null   object
#  5   tenure            7032 non-null   int64
#  6   PhoneService      7032 non-null   object
#  7   MultipleLines     7032 non-null   object
#  8   InternetService   7032 non-null   object
#  9   OnlineSecurity    7032 non-null   object
#  10  OnlineBackup      7032 non-null   object
#  11  DeviceProtection  7032 non-null   object
#  12  TechSupport       7032 non-null   object
#  13  StreamingTV       7032 non-null   object
#  14  StreamingMovies   7032 non-null   object
#  15  Contract          7032 non-null   object
# ...

# %%
df.describe()
# Out:
#        SeniorCitizen       tenure  MonthlyCharges  TotalCharges
# count    7032.000000  7032.000000     7032.000000   7032.000000
# mean        0.162400    32.421786       64.798208   2283.300441
# std         0.368844    24.545260       30.085974   2266.771362
# min         0.000000     1.000000       18.250000     18.800000
# 25%         0.000000     9.000000       35.587500    401.450000
# 50%         0.000000    29.000000       70.350000   1397.475000
# 75%         0.000000    55.000000       89.862500   3794.737500
# max         1.000000    72.000000      118.750000   8684.800000

# %% [markdown]
# **Many columns are categorical, meaning I will eventually need to convert them to dummy variables.**

# %% [markdown]
# #  Exploratory Data Analysis
#
# ## General Feature Exploration

# %% [markdown]
# **Display the balance of the class labels (Churn).**

# %%
sns.countplot(df,x='Churn')
# Out:
# <Axes: xlabel='Churn', ylabel='count'>

# %% [markdown]
# **This graph shows that it is not an imbalanced data**

# %% [markdown]
# **Explore the distrbution of TotalCharges between Churn categories with a Violin Plot.**

# %%
sns.violinplot(df,x='Churn',y='TotalCharges')
# Out:
# <Axes: xlabel='Churn', ylabel='TotalCharges'>

# %% [markdown]
# **Create a boxplot showing the distribution of TotalCharges per Contract type, also add in a hue coloring based on the Churn class.**

# %%
plt.figure(figsize=(12,4),dpi=200)
sns.boxplot(df,x='Contract',y='TotalCharges',hue='Churn')
# Out:
# <Axes: xlabel='Contract', ylabel='TotalCharges'>

# %% [markdown]
# **Create a bar plot showing the correlation to the class label.**
# **some features have too many unique instances for such an analysis, so I'll drop those columns**

# %%
df.nunique()
# Out:
# customerID          7032
# gender                 2
# SeniorCitizen          2
# Partner                2
# Dependents             2
# tenure                72
# PhoneService           2
# MultipleLines          3
# InternetService        3
# OnlineSecurity         3
# OnlineBackup           3
# DeviceProtection       3
# TechSupport            3
# StreamingTV            3
# StreamingMovies        3
# Contract               3
# PaperlessBilling       2
# PaymentMethod          4
# MonthlyCharges      1584
# TotalCharges        6530
# Churn                  2
# dtype: int64

# %% [markdown]
# **There are some ways to convert the categorical features into numeric variables. Each features don't have many numbers of unique item so one-hot encoding would be better this time.**

# %%
df_corr = pd.get_dummies(df.drop(['customerID','tenure','MonthlyCharges','TotalCharges'],axis=1))
df_corr.corr()['Churn_Yes'].drop(labels=['Churn_Yes','Churn_No']).sort_values()
# Out:
# Contract_Two year                         -0.301552
# StreamingMovies_No internet service       -0.227578
# OnlineBackup_No internet service          -0.227578
# InternetService_No                        -0.227578
# DeviceProtection_No internet service      -0.227578
# TechSupport_No internet service           -0.227578
# OnlineSecurity_No internet service        -0.227578
# StreamingTV_No internet service           -0.227578
# PaperlessBilling_No                       -0.191454
# Contract_One year                         -0.178225
# OnlineSecurity_Yes                        -0.171270
# TechSupport_Yes                           -0.164716
# Dependents_Yes                            -0.163128
# Partner_Yes                               -0.149982
# PaymentMethod_Credit card (automatic)     -0.134687
# InternetService_DSL                       -0.124141
# PaymentMethod_Bank transfer (automatic)   -0.118136
# PaymentMethod_Mailed check                -0.090773
# ...

# %%
SR_corr =  df_corr.corr()['Churn_Yes'].drop(labels=['Churn_Yes','Churn_No']).sort_values()

# %%
plt.figure(figsize=(10,4),dpi=200)
sns.barplot(x=SR_corr.index, y=SR_corr.values,).set_title('Feature Correlation To Yes_Churn')
plt.xticks(rotation=90);

# %% [markdown]
# ---
# ---
#
# # Churn Analysis
#
# **This section focuses on segementing customers based on their tenure, creating "cohorts", allowing us to examine differences between customer cohort segments.**

# %%
df['Contract'].unique()
# Out:
# array(['Month-to-month', 'One year', 'Two year'], dtype=object)

# %% [markdown]
# **Create a histogram displaying the distribution of 'tenure' column, which is the amount of months a customer was or has been on a customer.**

# %%
plt.figure(dpi=200)
sns.displot(df,x='tenure',bins=60,height=5,aspect=2);

# %%
df['tenure']
# Out:
# 0        1
# 1       34
# 2        2
# 3       45
# 4        2
#         ..
# 7027    24
# 7028    72
# 7029    11
# 7030     4
# 7031    66
# Name: tenure, Length: 7032, dtype: int64

# %%
plt.figure(figsize=(10,3),dpi=200)
sns.displot(data=df,x='tenure',bins=70,col='Contract',row='Churn');

# %% [markdown]
# **Display a scatter plot of Total Charges versus Monthly Charges, and color hue by Churn.**

# %%
plt.figure(figsize=(9,4),dpi=150)
sns.scatterplot(df,x='MonthlyCharges',y='TotalCharges',hue='Churn',alpha=0.5)
# Out:
# <Axes: xlabel='MonthlyCharges', ylabel='TotalCharges'>

# %% [markdown]
# ### Creating Cohorts based on Tenure
#
# **Let's begin by treating each unique tenure length as its own cohort.**

# %%
tenura_Churn_rate = []
for i in range(1,73):
    rate = len(df[(df['tenure']==i) & (df['Churn'] == 'Yes')])/len(df[df['tenure']==i])*100
    tenura_Churn_rate.append(rate)

# %%
tenura_Churn_rate
# Out:
# [61.99021207177814,
#  51.68067226890757,
#  47.0,
#  47.159090909090914,
#  48.1203007518797,
#  36.36363636363637,
#  38.93129770992366,
#  34.146341463414636,
#  38.655462184873954,
#  38.793103448275865,
#  31.313131313131315,
#  32.47863247863248,
#  34.862385321100916,
#  31.57894736842105,
#  37.37373737373738,
#  35.0,
#  29.88505747126437,
#  24.742268041237114,
#  26.027397260273972,
#  25.352112676056336,
#  26.984126984126984,
#  30.0,
#  15.294117647058824,
#  24.46808510638298,
#  29.11392405063291,
#  18.9873417721519,
#  18.055555555555554,
#  21.052631578947366,
#  20.833333333333336,
#  22.22222222222222,
#  24.615384615384617,
#  27.536231884057973,
#  21.875,
#  18.461538461538463,
#  17.045454545454543,
#  20.0,
#  23.076923076923077,
#  22.033898305084744,
#  25.0,
#  20.3125,
#  20.0,
#  21.53846153846154,
#  23.076923076923077,
#  11.76470588235294,
#  9.836065573770492,
#  16.216216216216218,
#  20.588235294117645,
#  14.0625,
#  22.727272727272727,
# ...

# %%
ser_tenura = pd.Series(data=tenura_Churn_rate,index=range(1,73),name='tenura')
ser_tenura
# Out:
# 1     61.990212
# 2     51.680672
# 3     47.000000
# 4     47.159091
# 5     48.120301
#         ...
# 68     9.000000
# 69     8.421053
# 70     9.243697
# 71     3.529412
# 72     1.657459
# Name: tenura, Length: 72, dtype: float64

# %% [markdown]
# **Now that I have Churn Rate per tenure group 1-72 months, create a plot showing churn rate per months of tenure.**

# %%
plt.figure(figsize=(10,4),dpi=150)
plt.plot(ser_tenura.index, ser_tenura.values) 
plt.xlabel('tenure')
plt.ylabel('Churn percentage');

# %% [markdown]
# **You should have cohorts 1-72 months with a general trend of the longer the tenure of the cohort, the less of a churn rate. This makes sense as you are less likely to stop service the longer you've had it.**

# %% [markdown]
# ### Broader Cohort Groups
# **Based on the tenure column values, create a new column called Tenure Cohort that creates 4 separate categories:**
#    * '0-12 Months'
#    * '12-24 Months'
#    * '24-48 Months'
#    * 'Over 48 Months'

# %%
df['tenure']
# Out:
# 0        1
# 1       34
# 2        2
# 3       45
# 4        2
#         ..
# 7027    24
# 7028    72
# 7029    11
# 7030     4
# 7031    66
# Name: tenure, Length: 7032, dtype: int64

# %%
def cohort(tenure):
    if tenure < 13:
        return '0-12 Months'
    elif tenure < 25:
        return '12-24 Months'
    elif tenure < 49:
        return '24-48 Months'
    else:
        return 'Over 48 Months'

# %%
df['Tenure_Cohort'] = df['tenure'].apply(cohort)

# %%
df[['tenure','Tenure_Cohort']].head()
# Out:
#    tenure Tenure_Cohort
# 0       1   0-12 Months
# 1      34  24-48 Months
# 2       2   0-12 Months
# 3      45  24-48 Months
# 4       2   0-12 Months

# %% [markdown]
# **Create a scatterplot of Total Charges versus Monthly Charts,colored by Tenure Cohort**

# %%
plt.figure(figsize=(10,5),dpi=150)
sns.scatterplot(df,x='MonthlyCharges',y='TotalCharges',hue='Tenure_Cohort',alpha=0.5)
# Out:
# <Axes: xlabel='MonthlyCharges', ylabel='TotalCharges'>

# %% [markdown]
# **Create a count plot showing the churn count per cohort.**

# %%
plt.figure(figsize=(10,4),dpi=150)
sns.countplot(data=df,x=df['Tenure_Cohort'],hue='Churn')
# Out:
# <Axes: xlabel='Tenure_Cohort', ylabel='count'>

# %% [markdown]
# **Create a grid of Count Plots showing counts per Tenure Cohort, separated out by contract type and colored by the Churn hue.**

# %%
sns.catplot(x='Tenure_Cohort',data=df,kind='count',col='Contract',hue='Churn')

# %% [markdown]
# -----
#
# # Predictive Modeling
#
# **Let's explore some different tree based methods: A Single Decision Tree, Random Forest, XG Boosting.**

# %% [markdown]
# ## Single Decision Tree

# %% [markdown]
# As proprocessing the data, Let's do a couple of tasks below
# ・drop ID column
# ・change the target column to 1,0
# ・get dummyvariables

# %%
df['Churn'] = df['Churn'].map({'No':0,'Yes':1})

# %%
X = pd.get_dummies(df.drop(['customerID','Churn'],axis=1),drop_first=True)

# %%
X
# Out:
#       SeniorCitizen  tenure  MonthlyCharges  TotalCharges  gender_Male  \
# 0                 0       1           29.85         29.85            0
# 1                 0      34           56.95       1889.50            1
# 2                 0       2           53.85        108.15            1
# 3                 0      45           42.30       1840.75            1
# 4                 0       2           70.70        151.65            0
# ...             ...     ...             ...           ...          ...
# 7027              0      24           84.80       1990.50            1
# 7028              0      72          103.20       7362.90            0
# 7029              0      11           29.60        346.45            0
# 7030              1       4           74.40        306.60            1
# 7031              0      66          105.65       6844.50            1
#
#       Partner_Yes  Dependents_Yes  PhoneService_Yes  \
# 0               1               0                 0
# ...

# %%
y = df['Churn']
y
# Out:
# 0       0
# 1       0
# 2       1
# 3       0
# 4       1
#        ..
# 7027    0
# 7028    0
# 7029    0
# 7030    1
# 7031    0
# Name: Churn, Length: 7032, dtype: int64

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.tree import DecisionTreeClassifier,plot_tree

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=101)

# %% [markdown]
# **Decision Tree Perfomance.**

# %% [markdown]
# Let's take a look at what the best alpha for this model is

# %%
tree_model = DecisionTreeClassifier(random_state=101)
path = tree_model.cost_complexity_pruning_path(X_train, y_train)
eff_alphas, impurities = path.ccp_alphas, path.impurities

# %%
tree_models = []
for eff_alpha in eff_alphas:
    model = DecisionTreeClassifier(random_state=101, ccp_alpha=eff_alpha)
    model.fit(X_train, y_train)
    tree_models.append(model)

# %%
train_scores = [model.score(X_train, y_train) for model in tree_models]
test_scores = [model.score(X_test, y_test) for model in tree_models]
 
fig, ax = plt.subplots()
ax.set_xlabel("alpha")
ax.set_ylabel("accuracy")
ax.plot(eff_alphas, train_scores, marker="o", label="train", drawstyle="steps-post")
ax.plot(eff_alphas, test_scores, marker="o", label="test", drawstyle="steps-post")
ax.legend();

# %% [markdown]
# **the graph I showed above indicates alpha=0.015 is the best for this model. Let's see the accuracy when alpha is 0.015**

# %%
best_tree_model = DecisionTreeClassifier(ccp_alpha=0.015)
best_tree_model.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier(ccp_alpha=0.015)

# %%
tree_pred = best_tree_model.predict(X_test)

# %%
from sklearn.metrics import confusion_matrix,classification_report,ConfusionMatrixDisplay

# %%
print(classification_report(y_test,tree_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.82      0.93      0.87      1052
#            1       0.67      0.40      0.50       355
#
#     accuracy                           0.80      1407
#    macro avg       0.75      0.67      0.69      1407
# weighted avg       0.78      0.80      0.78      1407

# %%
ConfusionMatrixDisplay(confusion_matrix(y_test,tree_pred)).plot()

# %% [markdown]
# **This model does not seem to work properly to predict customer Churn.**
# **What is the important features in this model?**

# %%
pd.DataFrame(index=X.columns,data=best_tree_model.feature_importances_,columns=['Feature Importance'])
# Out:
#                                        Feature Importance
# SeniorCitizen                                    0.000000
# tenure                                           0.601278
# MonthlyCharges                                   0.000000
# TotalCharges                                     0.000000
# gender_Male                                      0.000000
# Partner_Yes                                      0.000000
# Dependents_Yes                                   0.000000
# PhoneService_Yes                                 0.000000
# MultipleLines_No phone service                   0.000000
# MultipleLines_Yes                                0.000000
# InternetService_Fiber optic                      0.398722
# InternetService_No                               0.000000
# OnlineSecurity_No internet service               0.000000
# OnlineSecurity_Yes                               0.000000
# OnlineBackup_No internet service                 0.000000
# ...

# %%
plot_tree(best_tree_model, filled=True, feature_names=X.columns);

# %% [markdown]
# ## Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier

# %% [markdown]
# **I use same ccp_alpha  as the one I set in the dicision tree model.**

# %%
rf_model = RandomForestClassifier(ccp_alpha=0.015)

# %%
rf_model.fit(X_train,y_train)
# Out:
# RandomForestClassifier(ccp_alpha=0.015)

# %%
rf_pred = rf_model.predict(X_test)

# %%
print(classification_report(y_test,rf_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.78      0.98      0.87      1052
#            1       0.80      0.20      0.32       355
#
#     accuracy                           0.78      1407
#    macro avg       0.79      0.59      0.59      1407
# weighted avg       0.79      0.78      0.73      1407

# %%
ConfusionMatrixDisplay(confusion_matrix(y_test,rf_pred)).plot()

# %% [markdown]
# **Compared to the decision tree model I created, a precision score increased a bit but a recall decreased (They are trade-off relationship).
# We need to improvef-1 score. Let's see a boosting model.**

# %% [markdown]
# ## Boosted Trees

# %%
from xgboost import XGBClassifier

# %%
boost_model = XGBClassifier(learing_rate=0.1)

# %%
eval_set = [(X_test, y_test)]
boost_model.fit(X_train, y_train, eval_set=eval_set, verbose=True)
# Out:
# [0]	validation_0-logloss:0.49590
# [1]	validation_0-logloss:0.46144
# [2]	validation_0-logloss:0.44163
# [3]	validation_0-logloss:0.43064
# [4]	validation_0-logloss:0.42245
# [5]	validation_0-logloss:0.41906
# [6]	validation_0-logloss:0.41797
# [7]	validation_0-logloss:0.41670
# [8]	validation_0-logloss:0.41638
# [9]	validation_0-logloss:0.41571
# [10]	validation_0-logloss:0.41510
# [11]	validation_0-logloss:0.41519
# [12]	validation_0-logloss:0.41532
# [13]	validation_0-logloss:0.41657
# [14]	validation_0-logloss:0.41673
# [15]	validation_0-logloss:0.41692
# [16]	validation_0-logloss:0.41743
# [17]	validation_0-logloss:0.41795
# [18]	validation_0-logloss:0.42005
# [19]	validation_0-logloss:0.42059
# /Users/kodaikunimitsu/anaconda3/lib/python3.11/site-packages/xgboost/core.py:160: UserWarning: [16:59:09] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:742:
# Parameters: { "learing_rate" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# ...

# %%
boost_pred = boost_model.predict(X_test)

# %%
print(classification_report(y_test,boost_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.86      0.90      0.88      1052
#            1       0.66      0.55      0.60       355
#
#     accuracy                           0.82      1407
#    macro avg       0.76      0.73      0.74      1407
# weighted avg       0.81      0.82      0.81      1407

# %%
ConfusionMatrixDisplay(confusion_matrix(y_test,boost_pred)).plot()

# %%
boost_important = boost_model.feature_importances_

# %%
imp_feats = pd.DataFrame(index=X.columns,data=boost_important,columns=['Importance in Boosting model'])
imp_feats
# Out:
#                                        Importance in Boosting model
# SeniorCitizen                                              0.010278
# tenure                                                     0.028964
# MonthlyCharges                                             0.008769
# TotalCharges                                               0.009752
# gender_Male                                                0.007134
# Partner_Yes                                                0.006304
# Dependents_Yes                                             0.006889
# PhoneService_Yes                                           0.012077
# MultipleLines_No phone service                             0.000000
# MultipleLines_Yes                                          0.014177
# InternetService_Fiber optic                                0.399086
# InternetService_No                                         0.063652
# OnlineSecurity_No internet service                         0.000000
# ...

# %%
plt.figure(figsize=(14,6),dpi=200)
sns.barplot(data=imp_feats.sort_values('Importance in Boosting model'),x=imp_feats.sort_values('Importance in Boosting model').index,y='Importance in Boosting model')
plt.xticks(rotation=90);

# %% [markdown]
# **This graph shows that the boost model put more wight on 'InternetService' and 'Contract' columns than the tree dicision model did**

# %% [markdown]
# **Lastly, let's check with kfoldCV to see wheter this model overfitted testdata or not.**

# %%
from sklearn.metrics import log_loss

# %%
boost_proba = boost_model.predict_proba(X_test)
log_loss(y_test, boost_proba)
# Out:
# 0.41510409421488736

# %%
from sklearn.model_selection import cross_val_score,KFold

# %%
cv = KFold(n_splits=5, shuffle=True)
scores = cross_val_score(boost_model, X, y, scoring='neg_log_loss', cv=cv, n_jobs=-1)
# Out:
# /Users/kodaikunimitsu/anaconda3/lib/python3.11/site-packages/xgboost/core.py:160: UserWarning: [17:32:31] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:742:
# Parameters: { "learing_rate" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/kodaikunimitsu/anaconda3/lib/python3.11/site-packages/xgboost/core.py:160: UserWarning: [17:32:31] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:742:
# Parameters: { "learing_rate" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/kodaikunimitsu/anaconda3/lib/python3.11/site-packages/xgboost/core.py:160: UserWarning: [17:32:32] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:742:
# Parameters: { "learing_rate" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/kodaikunimitsu/anaconda3/lib/python3.11/site-packages/xgboost/core.py:160: UserWarning: [17:32:32] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:742:
# Parameters: { "learing_rate" } are not used.
#
# ...

# %%
abs(scores.mean())
# Out:
# 0.47034609663544985

# %% [markdown]
# **Analyzing the results, which model performed best?**

# %% [markdown]
# **Judging from f1 score and logloss, boost model is the most accurate.**

# %% [markdown]
# ### Fin!
